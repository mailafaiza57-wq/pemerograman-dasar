# %% [markdown]
# <a href="https://colab.research.google.com/github/mailafaiza57-wq/pemerograman-dasar/blob/main/coba_coba_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nama = "tokopedia"
harga_barang = "25000"
jumlah_beli = "3"
gratis_ongkir = "true"

print (nama)
print (harga_barang)
print (jumlah_beli)
print (gratis_ongkir)
# Out:
# tokopedia
# 25000
# 3
# true
